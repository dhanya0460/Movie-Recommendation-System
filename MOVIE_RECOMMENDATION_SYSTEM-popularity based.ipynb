# %% [markdown]
# # **Movie Recommendation System**:
# Popularity based:how popular it is with other users,
# Content based:based on what we watch ,
# Collaborative based:on the basis of kind of similar interest others have like mine

# %% [markdown]
# LOADING LIBRARIES

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# LOADING DATA

# %%
movies  = pd.read_csv('/content/movies.csv')
ratings = pd.read_csv('/content/ratings.csv')

# %% [markdown]
# EXPLORATORY DATA (EDA)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       16     4.0  1217897793
# 1       1       24     1.5  1217895807
# 2       1       32     4.0  1217896246
# 3       1       47     4.0  1217896556
# 4       1       50     4.0  1217896523

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10329 entries, 0 to 10328
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  10329 non-null  int64
#  1   title    10329 non-null  object
#  2   genres   10329 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 242.2+ KB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105339 entries, 0 to 105338
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     105339 non-null  int64
#  1   movieId    105339 non-null  int64
#  2   rating     105339 non-null  float64
#  3   timestamp  105339 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.2 MB

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  105339.000000  105339.000000  105339.000000  1.053390e+05
# mean      364.924539   13381.312477       3.516850  1.130424e+09
# std       197.486905   26170.456869       1.044872  1.802660e+08
# min         1.000000       1.000000       0.500000  8.285650e+08
# 25%       192.000000    1073.000000       3.000000  9.711008e+08
# 50%       383.000000    2497.000000       3.500000  1.115154e+09
# 75%       557.000000    5991.000000       4.000000  1.275496e+09
# max       668.000000  149532.000000       5.000000  1.452405e+09

# %%
ratings['userId'].nunique()
# Out:
# 668

# %%
movies['movieId'].nunique(), ratings['movieId'].nunique()
# Out:
# (10329, 10325)

# %%
movies['genres'] = movies['genres'].str.split('|')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
# 5                          [Action, Crime, Thriller]
# 6                                  [Comedy, Romance]
# 7                              [Adventure, Children]
# 8                                           [Action]
# 9                      [Action, Adventure, Thriller]

# %%
movies2 = movies.explode('genres')

# %%
movies2.head(20)
# Out:
#    movieId                               title     genres
# 0        1                    Toy Story (1995)  Adventure
# 0        1                    Toy Story (1995)  Animation
# 0        1                    Toy Story (1995)   Children
# 0        1                    Toy Story (1995)     Comedy
# 0        1                    Toy Story (1995)    Fantasy
# 1        2                      Jumanji (1995)  Adventure
# 1        2                      Jumanji (1995)   Children
# 1        2                      Jumanji (1995)    Fantasy
# 2        3             Grumpier Old Men (1995)     Comedy
# 2        3             Grumpier Old Men (1995)    Romance
# 3        4            Waiting to Exhale (1995)     Comedy
# 3        4            Waiting to Exhale (1995)      Drama
# 3        4            Waiting to Exhale (1995)    Romance
# 4        5  Father of the Bride Part II (1995)     Comedy
# 5        6                         Heat (1995)     Action
# 5        6                         Heat (1995)      Crime
# 5        6                         Heat (1995)   Thriller
# 6        7                      Sabrina (1995)     Comedy
# 6        7                      Sabrina (1995)    Romance
# 7        8                 Tom and Huck (1995)  Adventure

# %%
merged_info = pd.merge(ratings,movies2, on=['movieId'], how='inner')
merged_info.head(31)
print(merged_info.groupby('genres').agg({'title':'nunique', 'rating':'mean'}).reset_index().rename(columns={'title':'unique_movie_count','rating':'mean_rating'}))
# Out:
#                 genres  unique_movie_count  mean_rating
# 0   (no genres listed)                   7     3.071429
# 1               Action                1736     3.451450
# 2            Adventure                1164     3.518027
# 3            Animation                 400     3.635350
# 4             Children                 540     3.439429
# 5               Comedy                3513     3.420996
# 6                Crime                1440     3.642392
# 7          Documentary                 415     3.643035
# 8                Drama                5217     3.650266
# 9              Fantasy                 670     3.500459
# 10           Film-Noir                 195     3.913636
# 11              Horror                1001     3.281097
# 12                IMAX                 152     3.641821
# 13             Musical                 409     3.571962
# 14             Mystery                 675     3.652043
# 15             Romance                1788     3.544255
# 16              Sci-Fi                 858     3.454481
# 17            Thriller                2187     3.495561
# 18                 War                 503     3.783202
# 19             Western                 235     3.565687

# %%
merged_info.head()
# Out:
#    userId  movieId  rating   timestamp          title genres
# 0       1       16     4.0  1217897793  Casino (1995)  Crime
# 1       1       16     4.0  1217897793  Casino (1995)  Drama
# 2       9       16     4.0   842686699  Casino (1995)  Crime
# 3       9       16     4.0   842686699  Casino (1995)  Drama
# 4      12       16     1.5  1144396284  Casino (1995)  Crime

# %%
movies2['genres'].unique()
# Out:
# array(['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy',
#        'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror',
#        'Mystery', 'Sci-Fi', 'IMAX', 'War', 'Musical', 'Documentary',
#        'Western', 'Film-Noir', '(no genres listed)'], dtype=object)

# %%
movies2['genres'].nunique()
# Out:
# 20

# %%
movies2 = movies2[movies2['genres']!='(no genres listed)']

# %%
movies2['genres'].nunique()
# Out:
# 19

# %% [markdown]
# POPULARITY BASED RECOMMENDATION

# %%
def TopNPopularMovies(genre,num_ratings_threshold,topN=5):
  popularity_df = merged_info.groupby(['genres','title']).agg({'rating':['mean','size']}).reset_index()
  popularity_df.columns=['genre','title','ratings_mean','ratings_counts']


  topN_recommendations = popularity_df[(popularity_df['genre']==genre) & (popularity_df['ratings_counts']>=num_ratings_threshold)].sort_values(by=['ratings_mean'],ascending = False).head(topN)

  topN_recommendations['S.No'] = list(range(1,len(topN_recommendations)+1))
  topN_recommendations.index=range(len(topN_recommendations))
  topN_recommendations.columns=['Genre','Movie Title','Average movie ratings','Number Reviews','S.No']
  return topN_recommendations[['S.No','Movie Title','Average movie ratings','Number Reviews']]

# %%
genre = 'Animation'
num_ratings_threshold = 100
topN = 10
TopNPopularMovies(genre=genre,
                  num_ratings_threshold=num_ratings_threshold,
                  topN=topN)
# Out:
#    S.No                  Movie Title  Average movie ratings  Number Reviews
# 0     1      Incredibles, The (2004)               3.926471             102
# 1     2           Toy Story 2 (1999)               3.913462             104
# 2     3             Toy Story (1995)               3.907328             232
# 3     4          Finding Nemo (2003)               3.888889             117
# 4     5        Monsters, Inc. (2001)               3.879310             116
# 5     6        Lion King, The (1994)               3.770950             179
# 6     7                 Shrek (2001)               3.756329             158
# 7     8         Bug's Life, A (1998)               3.607843             102
# 8     9               Aladdin (1992)               3.602094             191
# 9    10  Beauty and the Beast (1991)               3.576923             143

# %%
genre = 'Action'
num_ratings_threshold = 100
topN = 10
TopNPopularMovies(genre=genre,
                  num_ratings_threshold=num_ratings_threshold,
                  topN=topN)
# Out:
#    S.No                                        Movie Title  \
# 0     1                                 Matrix, The (1999)
# 1     2  Star Wars: Episode V - The Empire Strikes Back...
# 2     3  Raiders of the Lost Ark (Indiana Jones and the...
# 3     4                                   Inception (2010)
# 4     5          Star Wars: Episode IV - A New Hope (1977)
# 5     6                                  Fight Club (1999)
# 6     7                                Blade Runner (1982)
# 7     8                         Princess Bride, The (1987)
# 8     9                                      Aliens (1986)
# 9    10                            Dark Knight, The (2008)
#
#    Average movie ratings  Number Reviews
# 0               4.264368             261
# 1               4.228070             228
# 2               4.212054             224
# 3               4.189320             103
# 4               4.188645             273
# 5               4.188406             207
# 6               4.169872             156
# 7               4.163743             171
# 8               4.146497             157
# 9               4.141732             127
